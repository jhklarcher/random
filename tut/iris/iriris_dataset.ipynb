# %% [markdown]
# # Primeiros passos em machine learning
#
# Dataset: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/

# %%
import pandas as pd # Importa o Pandas

arquivo = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data' # Nome e local do arquivo
nomes_col = ['comp_sepala', 'larg_sepala', 'comp_petala', 'larg_petala', 'especie'] # Títulos das colunas

df = pd.read_csv(arquivo, names=nomes_col) # Cria um dataframe do pandas com o arquivo e nomes de colunas especificados

# %%
df.shape # Verifica o número de linhas e colunas
# Out:
# (150, 5)

# %%
df.head() # Verificar os primeiros itens do dataframe
# Out:
#    comp_sepala  larg_sepala  comp_petala  larg_petala      especie
# 0          5.1          3.5          1.4          0.2  Iris-setosa
# 1          4.9          3.0          1.4          0.2  Iris-setosa
# 2          4.7          3.2          1.3          0.2  Iris-setosa
# 3          4.6          3.1          1.5          0.2  Iris-setosa
# 4          5.0          3.6          1.4          0.2  Iris-setosa

# %%
df.describe() # Demonstra as principais estatística do dataframe
# Out:
#        comp_sepala  larg_sepala  comp_petala  larg_petala
# count   150.000000   150.000000   150.000000   150.000000
# mean      5.843333     3.054000     3.758667     1.198667
# std       0.828066     0.433594     1.764420     0.763161
# min       4.300000     2.000000     1.000000     0.100000
# 25%       5.100000     2.800000     1.600000     0.300000
# 50%       5.800000     3.000000     4.350000     1.300000
# 75%       6.400000     3.300000     5.100000     1.800000
# max       7.900000     4.400000     6.900000     2.500000

# %%
import seaborn as sns # Importa a biblioteca Seaborn
sns.set(style='ticks') # Define o "estilo" que será usado nos gráficos

# %%
sns.boxplot(data=df) # Cria um gráfico com boxplot para cada atributo das flores

# %%
sns.pairplot(df, hue="especie") # Cria uma matriz de dispersão separando as espécies por cor

# %%
y = df['especie'] # Cria o dataframe "objetivo", que é o com as espécies que queremos prever
X = df.drop(['especie'], axis=1) # Cria um dataframe com os dados de entrada para as previsões

# %%
from sklearn.model_selection import train_test_split # Importa parte do sklearn para dividir os dados de entrada entre treino e teste

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, random_state=0) # Divide os dados de entrada entre treino e teste

# %%
from sklearn.tree import DecisionTreeClassifier # Importa o modelo de classificação de Árvores de Decisão

# %%
modelo = DecisionTreeClassifier() # Atribui o modelo a uma variável

# %%
modelo.fit(X_treino, y_treino) # Treina o nosso modelo
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
modelo.score(X_teste, y_teste) # Verifica a acurácia do modelo
# Out:
# 0.9736842105263158

# %%
modelo.predict(X_teste) # Gera previsões com os dados de entrada de teste
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %%
y_teste # É possível comparar com os valores esperados
# Out:
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
# 86     Iris-versicolor
# 76     Iris-versicolor
# 71     Iris-versicolor
# 134     Iris-virginica
# 51     Iris-versicolor
# 73     Iris-versicolor
# 54     Iris-versicolor
# 63     Iris-versicolor
# 37         Iris-setosa
# 78     Iris-versicolor
# 90     Iris-versicolor
# 45         Iris-setosa
# 16         Iris-setosa
# 121     Iris-virginica
# 66     Iris-versicolor
# 24         Iris-setosa
# 8          Iris-setosa
# 126     Iris-virginica
# 22         Iris-setosa
# 44         Iris-setosa
# 97     Iris-versicolor
# 93     Iris-versicolor
# 26         Iris-setosa
# 137     Iris-virginica
# 84     Iris-versicolor
# 27         Iris-setosa
# 127     Iris-virginica
# 132     Iris-virginica
# 59     Iris-versicolor
# 18         Iris-setosa
# 83     Iris-versicolor
# Name: especie, dtype: object
